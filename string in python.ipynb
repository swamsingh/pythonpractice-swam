# %%
#strings
a = 'hello , wolrd'# single
b = "hello , world"#double
c = '''this is a
multi line string'''#multi line string

print( a)
print( b)
print( c)
# Out:
# hello , wolrd
# hello , world
# this is a
# multi line string

# %%
# indexing
my_string = "hello world"
print(my_string[0])
print(my_string[1])
print(my_string[5])
print(my_string[-1])
print(my_string[-7])
# Out:
# h
# e
#
# d
# o

# %%
#slicing [start:end+1:step]
my_string = "hello world"
print(my_string[0:14])
print(my_string[0:7])
print(my_string[2:10])
print(my_string[-6:12])
print(my_string[7:9])
# Out:
# hello world
# hello w
# llo worl
#  world
# or

# %%
#sring concatination amd repetation
string1 = "Hello"
string2 = "World"
result = string1 + " " + string2
print(result)
result1 = string1  + string2
print(result1)
print(result)
print(string1 * 3)
# Out:
# Hello World
# HelloWorld
# Hello World
# HelloHelloHello

# %%
# checking for substrings
my_string = "python programming"
print('pro' in my_string)
print('java' not in my_string)
# Out:
# True
# True

# %%
#lower and upper convert the string to lower or upper
text = "   Hello"
print(text.lower())
print(text.upper())
print(text.strip())
print(text)
# Out:
#    hello
#    HELLO
# Hello
#    Hello

# %%
# replace() replace a substring with another string
text = "hello world"
print(text.replace('world','python'))
# Out:
# hello python

# %%
#slpit() splits a string into list
text = "hello world"
print(text.split())
# Out:
# ['hello', 'world']

# %%
#join() joins elements of a list into a single string
words = ['hello','world','cherry']
print(' '.join(words))
# Out:
# hello world cherry

# %%
#string formatting
name = input("enter your name ")
age = int (input("enere your age "))
print("My name is {} and I am {} years old".format(name,age))
# Out:
# enter your name om
# enere your age 19
# My name is om and I am 19 years old

# %%
name = input("enter your name ")
age = int (input("enere your age "))
print("My name is {name} and I am {age} years old".)
# Out:
#   File "<ipython-input-31-f2b2cfbb35be>", line 3
#     print("My name is {name} and I am {age} years old".)
#                                                        ^
# SyntaxError: invalid syntax

# %%
#escaping
text = "hello \"world\""
print(text)
# Out:
# hello "world"

# %%
#comments
#inline ==> single statemnet
#multi line ==> multiple line comment
#docsrings ==> multiple line

# %%
s = "hello"
reversed = s[::-1]
print(reversed)
# Out:
# olleh

# %%
s = "programming"
extrect  = s[3:7]
print(extrect)
# Out:
# gram

# %%
s = "banana"
count = s.count('a')
print(count)
# Out:
# 3

# %%
s = "Hello world"
u = s.upper()
print(u)
# Out:
# HELLO WORLD

# %%
s = "hii world"
if s.startswith("hello"):
  print("The string starts with 'hello'")
else:
  print("The string does not start with 'hello'")
# Out:
# The string does not start with 'hello'

# %%
s = "hello world"
find = s.find('o')
print(find)
# Out:
# 4

# %%
t

# %%
a =("apple, banana, cherry")
text = a.split(" : ")
print(text)
# Out:
# ['apple, banana, cherry']

# %%
s = "abc123"
print(s.isalnum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1c9fbdb7cc4d> in <cell line: 1>()
# ----> 1 s = abc123
#       2 print(s.isalnum())
#
# NameError: name 'abc123' is not defined

# %%
a = ["python", "is", "fun"]
result = " ".join(a)
print(result)
# Out:
# python is fun
