# %%
n = 5
p = 65
for i in range(n):
  for j in range(i+1):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
# A
# B B
# C C C
# D D D D
# E E E E E

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i+1):

    print(chr(p),end=" ")

    p+=1
  print()
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E

# %%
n = 5
p = 65
for i in range(n):
  for j in range(i,n):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
# A A A A A
# B B B B
# C C C
# D D
# E

# %%
n = 5

for i in range(n):
  p = 65
  for j in range(i,n):
    print(chr(p),end=" ")
    p+=1
  print()
# Out:
# A B C D E
# A B C D
# A B C
# A B
# A

# %%
n = 5
p = 65
for i in range(n):
  for j in range(i,n):
    print(" ",end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
#           A
#         B B
#       C C C
#     D D D D
#   E E E E E

# %%
n = 5
p = 65
for i in range(n):
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
#   A A A A A
#     B B B B
#       C C C
#         D D
#           E

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i,n):
    print(" ",end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
    p+=1
  print()
# Out:
#           A
#         A B
#       A B C
#     A B C D
#   A B C D E

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
    p+=1
  print()
# Out:
#   A B C D E
#     A B C D
#       A B C
#         A B
#           A

# %%
n = 5
p = 65
for i in range(n):
  for j in range(i,n):
    print(" ",end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
  for j in range(i):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
#           A
#         B B B
#       C C C C C
#     D D D D D D D
#   E E E E E E E E E

# %%
n = 6
p = 65
for i in range(n):
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
#   A A A A A A A A A A A A
#     B B B B B B B B B B
#       C C C C C C C C
#         D D D D D D
#           E E E E
#             F F

# %%
n = 5
p = 65
for i in range(n):
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i):
    print(chr(p),end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")

  p+=1
  print()
# Out:
#   A A A A A
#     B B B B B
#       C C C C C
#         D D D D D
#           E E E E E

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i,n):
    print(" ",end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
    p+=1
  for j in range(i):
    print(chr(p),end=" ")
    p+=1
  print()
# Out:
#           A
#         A B C
#       A B C D E
#     A B C D E F G
#   A B C D E F G H I

# %%
n = 6
for i in range(n):
  p = 65
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
    p+=1
  for j in range(i,n):
    print(chr(p),end=" ")
    p+=1
  print()
# Out:
#   A B C D E F G H I J K L
#     A B C D E F G H I J
#       A B C D E F G H
#         A B C D E F
#           A B C D
#             A B

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i,n):
    print(" ",end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
    p+=1
  for j in range(i):
    print(chr(p),end=" ")
    p+=1
  print()
# Out:
#           A
#         A B C
#       A B C D D
#     A B C D E E E
#   A B C D E F F F F
