# %%
n = 5
p = 65
for i in range(n):
  for j in range(i+1):
    print(chr(p),end=" ")
  p+=2
  print()
# Out:
# A
# C C
# E E E
# G G G G
# I I I I I

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i+1):
    print(chr(p),end=" ")
    p+=2
  print()
# Out:
# A
# A C
# A C E
# A C E G
# A C E G I

# %%
n = 5
for i in  range(n):
  for j in range(i+1):
    if (i%2==0):
      print('a',end=" ")
    else:
      print("x",end=" ")
  print()
# Out:
# a
# x x
# a a a
# x x x x
# a a a a a

# %%
n = 5
for i in  range(n):
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    if (i%2==0):
      print('Z',end=" ")
    else:
      print("0",end=" ")
  print()
# Out:
#   Z Z Z Z Z
#     0 0 0 0
#       Z Z Z
#         0 0
#           Z

# %%
n = 5
p = 65
for i in range(n-1):
  for j in range(i,n):
    print(' ',end=" ")
  for j in range(i):
    print(chr(p),end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
  p+=1
  print()
for i in range(n):
  for j in range(i+1):
    print(' ',end=" ")
  for j in range(i,n-1):
    print(chr(p),end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
  p+=1
  print()
# Out:
#           A
#         B B B
#       C C C C C
#     D D D D D D D
#   E E E E E E E E E
#     F F F F F F F
#       G G G G G
#         H H H
#           I

# %%
n = 5
p = 65
for i in range(n-1):
  for j in range(i,n):
    print(' ',end=" ")
  for j in range(i):
    print(chr(p),end=" ")
  for j in range(i+1):
    print(chr(p),end=" ")
  p+=1
  print()
for i in range(n):
  for j in range(i+1):
    print(' ',end=" ")
  for j in range(i,n-1):
    print(chr(p),end=" ")
  for j in range(i,n):
    print(chr(p),end=" ")
  p-=1
  print()
# Out:
#           A
#         B B B
#       C C C C C
#     D D D D D D D
#   E E E E E E E E E
#     D D D D D D D
#       C C C C C
#         B B B
#           A

# %%
n = 5
p = 69

for i in range(n):
  for j in range(i+1):
    print(chr(p),end=" ")
  p-=1
  print()
# Out:
# E
# D D
# C C C
# B B B B
# A A A A A

# %%
n = 5
k = 69
for i in range(n):
  p = k
  for j in range(i):
    print(' ',end= " ")
  for j in range(i,n):
    print(chr(p),end=" ")
    p-=1
  k-=1
  print()
# Out:
# E D C B A
#   D C B A
#     C B A
#       B A
#         A

# %%
n = 5
for i in range(n):
  p = 65
  for j in range(i,n):
    print(' ',end= " ")
  for j in range(i):
    print(chr(p),end=" ")
    p+=1
  for j in range(i+1):
    print(chr(p),end=" " )
    p-=1
  print()
# Out:
#           A
#         A B A
#       A B C B A
#     A B C D C B A
#   A B C D E D C B A

# %%
n = 5
for i in range(n-1):
  p = 65
  for j in range(i,n):
    print(' ',end= " ")
  for j in range(i):
    print(chr(p),end=" ")
    p+=1
  for j in range(i+1):
    print(chr(p),end=" " )
    p-=1
  print()
for i in range(n):
  p = 65
  for j in range(i+1):
    print(' ',end= " ")
  for j in range(i,n-1):
    print(chr(p),end=" ")
    p+=1
  for j in range(i,n):
    print(chr(p),end=" " )
    p+=1
  print()
# Out:
#           A
#         A B A
#       A B C B A
#     A B C D C B A
#   A B C D E F G H I
#     A B C D E F G
#       A B C D E
#         A B C
#           A

# %%
s = "PYTHON"
n =len(s)
p = 0
for i in range(n):
  for j in range(i+1):
    print(s[p],end=" ")
  p+=1
  print()
# Out:
# P
# Y Y
# T T T
# H H H H
# O O O O O
# N N N N N N

# %%
s = "PYTHON"
n =len(s)
for i in range(n):
  p = 0
  for j in range(i+1):
    print(s[p],end=" ")
    p+=1
  print()
# Out:
# P
# P Y
# P Y T
# P Y T H
# P Y T H O
# P Y T H O N

# %%
s = "PYTHON"
n =len(s)
for i in range(n):
  p = 0
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    print(s[p],end=" ")
    p+=1
  print()
# Out:
#   P Y T H O N
#     P Y T H O
#       P Y T H
#         P Y T
#           P Y
#             P

# %%
s = "PYTHON"
n =len(s)
p = n-1
for i in range(n):
  for j in range(i+1):
    print(" ",end=" ")
  for j in range(i,n):
    print(s[p],end=" ")
  p-=1
  print()
# Out:
#   N N N N N N
#     O O O O O
#       H H H H
#         T T T
#           Y Y
#             P

# %%
s = "PYTHON"
n =len(s)
for i in range(n):
  p = n-1
  for j in range(i+1):
    print(s[p],end=" ")
    p-=1
  print()
# Out:
# N
# N O
# N O H
# N O H T
# N O H T Y
# N O H T Y P
