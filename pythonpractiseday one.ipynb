# %%
print("heyy aman", end="$")
print("or bata")
# Out:
# heyy aman/n$or bata

# %%
company = "regex"
print(f"my company name is {company}")
# Out:
# my company name is regex

# %%
name = "om"
age ="19"
print(f"my name is {name} ans i'm {age} year old")
# Out:
# my name is om ans i'm 19 year old

# %%
# .formate
print("hey my namr is ")

# %%
#python feaures
# python +> features
#
address = """ b 35 basant biagar
gopal pura """
print(address)
# Out:
#  b 35 basant biagar
# gopal pura

# %%
address1 = "'" b 35 basant biagar
gopal pura """
print(address)
# Out:
#   File "<ipython-input-6-e983fa1ba0e1>", line 2
#     gopal pura """
#                ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 3)

# %%
y = 10
y /= 3
y
# Out:
# 3.3333333333333335

# %%
# memebership opretor  (itrable)
"1" in "10"
# intejers are not itrable
# Out:
# True

# %%
6&12
# Out:
# 4

# %%
6|14 # bitwise or
# Out:
# 14

# %%
# xor
#number // 2**bit(right shift)
#number * 2**bit(left shift)
22<<3
# Out:
# 176

# %%
# == compare values
# is comapre memory refrence

# %%
number = 0

if (number > 0):
  print("integer")
else:
  print("neutral")
# Out:
# neutral

# %%
number = -6

if (number > 0 or number <0):
  print("integer")
else:
  print("neutral")
# Out:
# integer

# %%
number = -1
if (number > 0):
  print("integer")
elif (number < 0):
  print("negative")
else:
  print("neutral")
# Out:
# negative

# %%
x = 1
y = 2
if(x >y):
  print("y is smaller")
else:
  print("x is smaller")
# Out:
# x is smaller

# %%
x = 1
y = 2
z = 3
if(x>y and x>z):
  print("x is bigger")
elif(y>x and y>z):
  print("y is bigger")
else:
  print("z is bigger")
# Out:
# z is bigger

# %%
x = int(input("enter a number "))
if (x%2==0):
  print(f"{x} :is even number")
else:
  print(f"{x} :is odd number")
# Out:
# enter a number 100
# 100 :is even number

# %%
age = int(input("enter your age"))
if (age > 10 and age <18):
  print("young")
elif(age > 18 and age < 25):
  print("adult")
elif(age > 26 and age <60):
  print("citizen")
else:
  print("old")
# Out:
# enter your age99
# old
